# %%
# %load_ext autoreload

# %autoreload 2
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow.keras.callbacks as cb
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
from functools import partial
from model import TransformerEncoderClassifier
from experiment import create_model, fit_data
from data import get_datasets

# %%
MAX_LENGTH = 200 # Can test with smaller datasets, 200 default!
BATCH_SIZE = 32

(train_dataset, test_dataset), info = get_datasets(max_length=MAX_LENGTH, batch_size=BATCH_SIZE)

# %%
LR = 0.0001
VOCAB_SIZE = info.features['text'].encoder.vocab_size 
POS_ENC = True
LOAD_CHECKPOINT = False

transformer, optimizer, checkpoint, manager = create_model(models_dir="models_entmax", load_checkpoint=LOAD_CHECKPOINT, 
                           vocab_size=VOCAB_SIZE, use_positional_encoding=POS_ENC, run_eagerly=True, learning_rate=LR)
# Out:
# Not loading previously trained model. Training from scratch.

# %%
PATIENCE = 20
MAX_EPOCHS = 1000
USE_SPARSEMAX = True
results_dir="results_entmax"
models_dir="models_entmax"
data_dir="data"

model_history = fit_data(MAX_EPOCHS, transformer, optimizer, checkpoint, manager, train_dataset, 
                         test_dataset, results_dir, models_dir, use_sparsemax=USE_SPARSEMAX, patience=PATIENCE)
# Out:
# Epoch 1
# 	 Train Loss: 6.749056339263916
# 	 Test Accuracy=0.48778238892555237
# 	 Saved checkpoint better accuracy for epoch 1: models_entmax\ckpt-1
# Epoch 2
# 	 Train Loss: 2.3015928268432617
# 	 Test Accuracy=0.5274320244789124
# 	 Saved checkpoint better accuracy for epoch 2: models_entmax\ckpt-2
# Epoch 3
# 	 Train Loss: 1.76882803440094
# 	 Test Accuracy=0.650714635848999
# 	 Saved checkpoint better accuracy for epoch 3: models_entmax\ckpt-3
# Epoch 4
# 	 Train Loss: 1.293383002281189
# 	 Test Accuracy=0.5932688117027283
# Epoch 5
# 	 Train Loss: 1.0602197647094727
# 	 Test Accuracy=0.6188105344772339
# Epoch 6
# 	 Train Loss: 0.804266631603241
# 	 Test Accuracy=0.6913785338401794
# 	 Saved checkpoint better accuracy for epoch 6: models_entmax\ckpt-4
# Epoch 7
# 	 Train Loss: 0.6758939027786255
# 	 Test Accuracy=0.7763946652412415
# 	 Saved checkpoint better accuracy for epoch 7: models_entmax\ckpt-5
# Epoch 8
# 	 Train Loss: 0.5102909207344055
# 	 Test Accuracy=0.6994006633758545
# Epoch 9
# 	 Train Loss: 0.4108200669288635
# 	 Test Accuracy=0.763946533203125
# Epoch 10
# 	 Train Loss: 0.2863519489765167
# 	 Test Accuracy=0.8203780651092529
# 	 Saved checkpoint better accuracy for epoch 10: models_entmax\ckpt-6
# Epoch 11
# 	 Train Loss: 0.18944433331489563
# 	 Test Accuracy=0.816044270992279
# Epoch 12
# 	 Train Loss: 0.2073763757944107
# 	 Test Accuracy=0.8039649724960327
# Epoch 13
# 	 Train Loss: 0.12092963606119156
# 	 Test Accuracy=0.7763946652412415
# Epoch 14
# 	 Train Loss: 0.11965736001729965
# 	 Test Accuracy=0.8359612822532654
# 	 Saved checkpoint better accuracy for epoch 14: models_entmax\ckpt-7
# Epoch 15
# 	 Train Loss: 0.13758137822151184
# 	 Test Accuracy=0.8295989036560059
# Epoch 16
# 	 Train Loss: 0.07296937704086304
# 	 Test Accuracy=0.8412171602249146
# 	 Saved checkpoint better accuracy for epoch 16: models_entmax\ckpt-8
# Epoch 17
# 	 Train Loss: 0.08833184093236923
# 	 Test Accuracy=0.8358690738677979
# Epoch 18
# 	 Train Loss: 0.10654259473085403
# 	 Test Accuracy=0.8351314067840576
# Epoch 19
# 	 Train Loss: 0.07290010899305344
# 	 Test Accuracy=0.8340249061584473
# Epoch 20
# 	 Train Loss: 0.06268293410539627
# 	 Test Accuracy=0.8405717015266418
# Epoch 21
# 	 Train Loss: 0.05717867240309715
# 	 Test Accuracy=0.8412171602249146
# Epoch 22
# 	 Train Loss: 0.08035969734191895
# 	 Test Accuracy=0.8452743291854858
# 	 Saved checkpoint better accuracy for epoch 22: models_entmax\ckpt-9
# Epoch 23
# 	 Train Loss: 0.10144784301519394
# 	 Test Accuracy=0.8292300701141357
# Epoch 24
# 	 Train Loss: 0.048277415335178375
# 	 Test Accuracy=0.8343015313148499
# Epoch 25
# 	 Train Loss: 0.09830888360738754
# 	 Test Accuracy=0.8414937853813171
# Epoch 26
# 	 Train Loss: 0.03542560711503029
# 	 Test Accuracy=0.807837724685669
# Epoch 27
# 	 Train Loss: 0.028838055208325386
# 	 Test Accuracy=0.8381742835044861
# Epoch 28
# 	 Train Loss: 0.1453433483839035
# 	 Test Accuracy=0.847210705280304
# 	 Saved checkpoint better accuracy for epoch 28: models_entmax\ckpt-10
# Epoch 29
# 	 Train Loss: 0.040019188076257706
# 	 Test Accuracy=0.8065468072891235
# Epoch 30
# 	 Train Loss: 0.042162440717220306
# 	 Test Accuracy=0.8465652465820312
# Epoch 31
# 	 Train Loss: 0.0204194113612175
# 	 Test Accuracy=0.8443522453308105
# Epoch 32
# 	 Train Loss: 0.043944064527750015
# 	 Test Accuracy=0.8470262885093689
# Epoch 33
# 	 Train Loss: 0.05544406920671463
# 	 Test Accuracy=0.8190871477127075
# Epoch 34
# 	 Train Loss: 0.03414286673069
# 	 Test Accuracy=0.8383587002754211
# Epoch 35
# 	 Train Loss: 0.06906630843877792
# 	 Test Accuracy=0.845827579498291
# Epoch 36
# 	 Train Loss: 0.08231806010007858
# 	 Test Accuracy=0.8465652465820312
# Epoch 37
# 	 Train Loss: 0.04030827432870865
# 	 Test Accuracy=0.8452743291854858
# Epoch 38
# 	 Train Loss: 0.021546591073274612
# 	 Test Accuracy=0.8452743291854858
# Epoch 39
# 	 Train Loss: 0.03742056339979172
# 	 Test Accuracy=0.8484094142913818
# 	 Saved checkpoint better accuracy for epoch 39: models_entmax\ckpt-11
# Epoch 40
# 	 Train Loss: 0.05372830107808113
# 	 Test Accuracy=0.7872752547264099
# Epoch 41
# 	 Train Loss: 0.05104103684425354
# 	 Test Accuracy=0.8406639099121094
# Epoch 42
# 	 Train Loss: 0.022766295820474625
# 	 Test Accuracy=0.8088520169258118
# Epoch 43
# 	 Train Loss: 0.022375302389264107
# 	 Test Accuracy=0.837805449962616
# Epoch 44
# 	 Train Loss: 0.016069384291768074
# 	 Test Accuracy=0.8427847027778625
# Epoch 45
# 	 Train Loss: 0.06750220060348511
# 	 Test Accuracy=0.8224988579750061
# Epoch 46
# 	 Train Loss: 0.02954636700451374
# 	 Test Accuracy=0.844260036945343
# Epoch 47
# 	 Train Loss: 0.04529101029038429
# 	 Test Accuracy=0.8467496633529663
# Epoch 48
# 	 Train Loss: 0.01529279537498951
# 	 Test Accuracy=0.841124951839447
# Epoch 49
# 	 Train Loss: 0.013402470387518406
# 	 Test Accuracy=0.8485938310623169
# 	 Saved checkpoint better accuracy for epoch 49: models_entmax\ckpt-12
# Epoch 50
# 	 Train Loss: 0.028909113258123398
# 	 Test Accuracy=0.850530207157135
# 	 Saved checkpoint better accuracy for epoch 50: models_entmax\ckpt-13
# Epoch 51
# 	 Train Loss: 0.011381627060472965
# 	 Test Accuracy=0.8500691652297974
# Epoch 52
# 	 Train Loss: 0.020186835899949074
# 	 Test Accuracy=0.8193637728691101
# Epoch 53
# 	 Train Loss: 0.03802351653575897
# 	 Test Accuracy=0.8473029136657715
# Epoch 54
# 	 Train Loss: 0.0210499819368124
# 	 Test Accuracy=0.8480405807495117
# Epoch 55
# 	 Train Loss: 0.017842736095190048
# 	 Test Accuracy=0.8501613736152649
# Epoch 56
# 	 Train Loss: 0.019836755469441414
# 	 Test Accuracy=0.8413093686103821
# Epoch 57
# 	 Train Loss: 0.06109282746911049
# 	 Test Accuracy=0.8477639555931091
# Epoch 58
# 	 Train Loss: 0.021083712577819824
# 	 Test Accuracy=0.8459197878837585
# Epoch 59
# 	 Train Loss: 0.013513176701962948
# 	 Test Accuracy=0.8490548729896545
# Epoch 60
# 	 Train Loss: 0.014011867344379425
# 	 Test Accuracy=0.848778247833252
# Epoch 61
# 	 Train Loss: 0.01935669220983982
# 	 Test Accuracy=0.8173351883888245
# Epoch 62
# 	 Train Loss: 0.051035597920417786
# 	 Test Accuracy=0.847210705280304
# Epoch 63
# 	 Train Loss: 0.018174493685364723
# 	 Test Accuracy=0.8473029136657715
# Epoch 64
# 	 Train Loss: 0.015488960780203342
# 	 Test Accuracy=0.845827579498291
# Epoch 65
# 	 Train Loss: 0.03668105602264404
# 	 Test Accuracy=0.8331950306892395
# Epoch 66
# 	 Train Loss: 0.010206456296145916
# 	 Test Accuracy=0.8469340801239014
# Epoch 67
# 	 Train Loss: 0.012230108492076397
# 	 Test Accuracy=0.8402028679847717
# Epoch 68
# 	 Train Loss: 0.015387561172246933
# 	 Test Accuracy=0.8477639555931091
# Epoch 69
# 	 Train Loss: 0.018683787435293198
# 	 Test Accuracy=0.8444444537162781
# Epoch 70
# 	 Train Loss: 0.012629522010684013
# 	 Test Accuracy=0.8449054956436157
# 	 Stopping early after 20 steps of no improvement.
# 	 Restoring best model with best accuracy 0.850530207157135, from models_entmax\ckpt-13.
