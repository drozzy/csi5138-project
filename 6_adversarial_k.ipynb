# %%
# %load_ext autoreload

# %autoreload 2
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow.keras.callbacks as cb
import time
import numpy as np
from data import get_datasets
import matplotlib.pyplot as plt
import os
import shutil
from functools import partial
from data import get_datasets
from experiment import create_model
from sentiment import sentiment
import model_adv

# %%
(train_dataset, test_dataset), info = get_datasets()
encoder = info.features['text'].encoder
vocab_size=info.features['text'].encoder.vocab_size

# %%
transformer, _optimizer, _checkpoint, _manager = create_model(models_dir="checkpoints", load_checkpoint=True, 
                           vocab_size=vocab_size, use_positional_encoding=True, run_eagerly=True)

# adv = model_adv.create_model(models_dir="adv", load_checkpoint=False, run_eagerly=True, d_model=512)
# Out:
# Loaded previously trained model.

# %%
def kld(a1, a2) :
    #(B, *, A), #(B, *, A)
    a1 = tf.clip_by_value(a1, 0, 1)
    a2 = tf.clip_by_value(a2, 0, 1)
    log_a1 = tf.math.log(a1 + 1e-10)
    log_a2 = tf.math.log(a2 + 1e-10)

    kld = a1 * (log_a1 - log_a2)
    kld = tf.math.reduce_sum(kld)

    return kld

def jsd(p, q) :
    m = 0.5 * (p + q)
    jsd = 0.5 * (kld(p, m) + kld(q, m))
    print(jsd)
    
    return tf.expand_dims(jsd,-1)

# %%
EPOCHS = 100
D_MODEL = 128
def find_adv_k(x, y, transformer):
    """
    x - (batch, text)
    y - (batch, label)
    
    Passes x through transformer and receives y_logits, w, k.
    Creates an adversarial model - adv.
    Pass k through adv model and receives adv_k.
    Computes loss by passing (x, custom_k=adv_k) through transformer:
        Receives adv_y_logits, adv_w, adv_k (same k)
        loss_t = tf.keras.losses.binary_crossentropy(y_true=y, y_pred=adv_y_logits, from_logits=True)
        loss_k = - |k - adv_k|
        loss = loss_t + loss_k
    
    Returns: 
        k - original k
        w - original attention weights
        adv_k - adversarial k
        adv_w - adversarial attention weights w
        loss_k - the one that is maximized
        loss_t - transformer loss (the one that is minimized)
        loss - adversarial loss, e.g.  loss = loss_t = loss_k
    """
    y_logits, w, k = transformer(x, training=False)
    adv, optimizer = model_adv.create_model(models_dir="adv", load_checkpoint=False, 
                                            run_eagerly=True, d_model=D_MODEL)
    
    loss_t = tf.keras.losses.binary_crossentropy(y_true=y, y_pred=y_logits, from_logits=True)
    print(f'[{0}] Loss_t = {loss_t:<20.10}')

    for epoch in range(1, EPOCHS+1):        
        with tf.GradientTape() as tape:
            adv_k = adv(k, training=True)
            
            adv_y_logits, adv_w, adv_k2  = transformer(x, custom_k=adv_k, training=False)
            cond = tf.reduce_all(tf.equal(adv_k, adv_k2)).numpy()
            
            assert cond == True
            loss_t = tf.keras.losses.binary_crossentropy(y_true=y, y_pred=adv_y_logits, from_logits=True)
            
            loss_k = tf.math.reduce_sum(tf.math.abs(k - adv_k))

#             loss_k = jsd(k,adv_k)

            loss = (loss_t) - tf.math.log(loss_k)
        
        print(f'[{epoch:<2}] Loss_t = {loss_t:<20.10}  Loss_k = {loss_k:<20.10}   Loss = {loss:<20.10}')

        grads = tape.gradient(loss, adv.trainable_weights)                
        optimizer.apply_gradients(zip(grads, adv.trainable_weights))

# %%
for batch, (x, y) in enumerate(train_dataset):
    find_adv_k(x, y, transformer)
# Out:
# [0] Loss_t = 44.30617523
# [1 ] Loss_t = 40.44004822           Loss_k = 1772366.25             Loss = 26.05222321
# [2 ] Loss_t = 33.23210526           Loss_k = 1786517.375            Loss = 18.8363266
# [3 ] Loss_t = 26.02960396           Loss_k = 1803062.375            Loss = 11.62460709
# [4 ] Loss_t = 18.75469971           Loss_k = 1822144.625            Loss = 4.339175224
# [5 ] Loss_t = 11.55359459           Loss_k = 1843906.0              Loss = -2.873802185
# [6 ] Loss_t = 8.217758179           Loss_k = 1868928.125            Loss = -6.223117828
# [7 ] Loss_t = 10.31872177           Loss_k = 1898565.25             Loss = -4.137887001
# [8 ] Loss_t = 12.32525253           Loss_k = 1927975.875            Loss = -2.146728516
# [9 ] Loss_t = 12.90054893           Loss_k = 1954663.0              Loss = -1.585179329
# [10] Loss_t = 12.38732147           Loss_k = 1978487.75             Loss = -2.11052227
# [11] Loss_t = 11.08200264           Loss_k = 1999576.75             Loss = -3.4264431
# [12] Loss_t = 9.287704468           Loss_k = 2018316.0              Loss = -5.23006916
# [13] Loss_t = 7.418916225           Loss_k = 2035590.5              Loss = -7.10738039
# [14] Loss_t = 6.321320534           Loss_k = 2052513.75             Loss = -8.213254929
# [15] Loss_t = 6.456362724           Loss_k = 2071285.375            Loss = -8.087317467
# [16] Loss_t = 7.136322021           Loss_k = 2092838.75             Loss = -7.417710304
# [17] Loss_t = 7.562464714           Loss_k = 2117522.75             Loss = -7.003293037
# [18] Loss_t = 7.48344326            Loss_k = 2144917.75             Loss = -7.095168114
# [19] Loss_t = 6.946811676           Loss_k = 2174622.25             Loss = -7.645553589
# [20] Loss_t = 6.157101631           Loss_k = 2206390.0              Loss = -8.449766159
# [21] Loss_t = 5.44378376            Loss_k = 2239961.0              Loss = -9.178185463
# [22] Loss_t = 5.120725632           Loss_k = 2275024.25             Loss = -9.516776085
# [23] Loss_t = 5.214625359           Loss_k = 2310975.0              Loss = -9.438554764
# [24] Loss_t = 5.500266075           Loss_k = 2346665.25             Loss = -9.168239594
# [25] Loss_t = 5.59346962            Loss_k = 2381143.25             Loss = -9.089621544
# [26] Loss_t = 5.371945381           Loss_k = 2414206.25             Loss = -9.324935913
# [27] Loss_t = 4.908153534           Loss_k = 2445972.5              Loss = -9.801799774
# [28] Loss_t = 4.419311047           Loss_k = 2476984.5              Loss = -10.30324173
# [29] Loss_t = 4.174693108           Loss_k = 2508265.25             Loss = -10.56040859
# [30] Loss_t = 4.129811287           Loss_k = 2540817.0              Loss = -10.61818504
# [31] Loss_t = 4.158885479           Loss_k = 2575242.25             Loss = -10.60256958
# [32] Loss_t = 4.12261343            Loss_k = 2611896.75             Loss = -10.65297318
# [33] Loss_t = 3.9182446             Loss_k = 2650692.0              Loss = -10.87208652
# [34] Loss_t = 3.581759214           Loss_k = 2691444.75             Loss = -11.22382927
# [35] Loss_t = 3.258570194           Loss_k = 2733754.5              Loss = -11.56261635
# [36] Loss_t = 3.111047745           Loss_k = 2776925.25             Loss = -11.72580719
# [37] Loss_t = 3.155058384           Loss_k = 2820065.75             Loss = -11.69721222
# [38] Loss_t = 3.144293785           Loss_k = 2862271.5              Loss = -11.72283268
# [39] Loss_t = 2.950329065           Loss_k = 2903259.5              Loss = -11.93101597
# [40] Loss_t = 2.650922775           Loss_k = 2943171.75             Loss = -12.24407578
# [41] Loss_t = 2.452986956           Loss_k = 2982726.0              Loss = -12.45536137
# [42] Loss_t = 2.430109262           Loss_k = 3023040.5              Loss = -12.49166489
# [43] Loss_t = 2.408423662           Loss_k = 3065152.0              Loss = -12.52718449
# [44] Loss_t = 2.227935314           Loss_k = 3109328.75             Loss = -12.72198296
# [45] Loss_t = 1.97744453            Loss_k = 3155283.75             Loss = -12.98714447
# [46] Loss_t = 1.85718751            Loss_k = 3202193.5              Loss = -13.122159
# [47] Loss_t = 1.837682962           Loss_k = 3248761.5              Loss = -13.15610123
# [48] Loss_t = 1.737108707           Loss_k = 3294037.75             Loss = -13.27051544
# [49] Loss_t = 1.538012266           Loss_k = 3337976.5              Loss = -13.48286247
# [50] Loss_t = 1.392293453           Loss_k = 3381356.5              Loss = -13.64149475
# [51] Loss_t = 1.348976374           Loss_k = 3425531.5              Loss = -13.6977911
# [52] Loss_t = 1.273973227           Loss_k = 3471359.75             Loss = -13.78608322
# [53] Loss_t = 1.126520514           Loss_k = 3518929.25             Loss = -13.94714737
# [54] Loss_t = 0.997525692           Loss_k = 3567772.5              Loss = -14.08992577
# [55] Loss_t = 0.9463467598          Loss_k = 3616938.5              Loss = -14.15479088
# [56] Loss_t = 0.8972089291          Loss_k = 3665593.0              Loss = -14.21729183
# [57] Loss_t = 0.7989630699          Loss_k = 3713487.5              Loss = -14.32851982
# [58] Loss_t = 0.7047348022          Loss_k = 3761125.0              Loss = -14.43549347
# [59] Loss_t = 0.660459578           Loss_k = 3809368.0              Loss = -14.49251461
# [60] Loss_t = 0.6338989735          Loss_k = 3859065.25             Loss = -14.53203678
# [61] Loss_t = 0.5765155554          Loss_k = 3910618.75             Loss = -14.6026907
# [62] Loss_t = 0.5163298845          Loss_k = 3963748.75             Loss = -14.67637062
# [63] Loss_t = 0.4898484945          Loss_k = 4017728.0              Loss = -14.71637917
# [64] Loss_t = 0.4708659053          Loss_k = 4071815.0              Loss = -14.74873352
# [65] Loss_t = 0.4357756674          Loss_k = 4125630.5              Loss = -14.7969532
# [66] Loss_t = 0.3958986998          Loss_k = 4179397.25             Loss = -14.84977913
# [67] Loss_t = 0.3701022267          Loss_k = 4233680.0              Loss = -14.88848019
# [68] Loss_t = 0.354957521           Loss_k = 4289041.5              Loss = -14.91661644
# [69] Loss_t = 0.3343210518          Loss_k = 4345820.0              Loss = -14.95040417
# [70] Loss_t = 0.3071992695          Loss_k = 4404032.0              Loss = -14.99083138
# [71] Loss_t = 0.2851834595          Loss_k = 4463433.0              Loss = -15.02624512
# [72] Loss_t = 0.2721535861          Loss_k = 4523653.5              Loss = -15.0526762
# [73] Loss_t = 0.2622026801          Loss_k = 4584313.0              Loss = -15.07594872
# [74] Loss_t = 0.2500313818          Loss_k = 4645227.0              Loss = -15.10131931
# [75] Loss_t = 0.2365359515          Loss_k = 4706406.5              Loss = -15.12789917
# [76] Loss_t = 0.2251105905          Loss_k = 4768127.0              Loss = -15.15235329
# [77] Loss_t = 0.2163654119          Loss_k = 4830743.0              Loss = -15.17414474
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e975b9da770e> in <module>
#       1 for batch, (x, y) in enumerate(train_dataset):
# ----> 2     find_adv_k(x, y, transformer)
#
# <ipython-input-17-c46950c04e68> in find_adv_k(x, y, transformer)
#      35             adv_k = adv(k, training=True)
#      36
# ---> 37             adv_y_logits, adv_w, adv_k2  = transformer(x, custom_k=adv_k, training=False)
#      38             cond = tf.reduce_all(tf.equal(adv_k, adv_k2)).numpy()
#      39
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/Deep-Learning/csi5138-project/model.py in call(self, inp, training, custom_k)
#     275
#     276         enc_padding_mask = create_padding_mask(inp)
# --> 277         enc_output, attention_weights, k = self.encoder(inp, training, enc_padding_mask, custom_k=custom_k)  # (batch_size, seq_len, d_model)
#     278         # enc_output.shape == (batch_size, seq_len, d_model)
#     279         if enc_padding_mask is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/Deep-Learning/csi5138-project/model.py in call(self, x, training, mask, custom_k)
#     246         for i in range(self.num_layers):
#     247
# --> 248             x, layer_weights, k = self.enc_layers[i](x, training, mask, custom_k=custom_k) # All the ks are the same here - keep the last one
#     249             attention_weights.append(layer_weights)
#     250
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/Deep-Learning/csi5138-project/model.py in call(self, x, training, mask, custom_k)
#     189
#     190     def call(self, x, training, mask, custom_k=None):
# --> 191         attn_output, attn_weights, k = self.mha(x, x, x, mask, custom_k=custom_k)  # (batch_size, input_seq_len, d_model)
#     192         attn_output = self.dropout1(attn_output, training=training)
#     193         out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/Deep-Learning/csi5138-project/model.py in call(self, v, k, q, mask, custom_k)
#     128         unsplit_k = k
#     129
# --> 130         v = self.wv(v)  # (batch_size, seq_len, d_model)
#     131
#     132
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/layers/core.py in call(self, inputs)
#    1043     if rank > 2:
#    1044       # Broadcasting is required for the inputs.
# -> 1045       outputs = standard_ops.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#    1046       # Reshape the output back to the original ndim of the input.
#    1047       if not context.executing_eagerly():
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/math_ops.py in tensordot(a, b, axes, name)
#    4074     a_reshape, a_free_dims, a_free_dims_static = _tensordot_reshape(a, a_axes)
#    4075     b_reshape, b_free_dims, b_free_dims_static = _tensordot_reshape(
# -> 4076         b, b_axes, True)
#    4077     ab_matmul = matmul(a_reshape, b_reshape)
#    4078     if isinstance(a_free_dims, list) and isinstance(b_free_dims, list):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/math_ops.py in _tensordot_reshape(a, axes, flipped)
#    3992       static shape of the free dimensions
#    3993     """
# -> 3994     if a.get_shape().is_fully_defined() and isinstance(axes, (list, tuple)):
#    3995       shape_a = a.get_shape().as_list()
#    3996       axes = [i if i >= 0 else i + len(shape_a) for i in axes]
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in get_shape(self)
#    1038   def get_shape(self):
#    1039     """Alias of Tensor.shape."""
# -> 1040     return self.shape
#    1041
#    1042   def _shape_as_list(self):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in shape(self)
#    1033       # `_tensor_shape` is declared and defined in the definition of
#    1034       # `EagerTensor`, in C.
# -> 1035       self._tensor_shape = tensor_shape.TensorShape(self._shape_tuple())
#    1036     return self._tensor_shape
#    1037
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in __init__(self, dims)
#     774       else:
#     775         # Got a list of dimensions
# --> 776         self._dims = [as_dimension(d) for d in dims_iter]
#     777
#     778   @property
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in <listcomp>(.0)
#     774       else:
#     775         # Got a list of dimensions
# --> 776         self._dims = [as_dimension(d) for d in dims_iter]
#     777
#     778   @property
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in as_dimension(value)
#     716     return value
#     717   else:
# --> 718     return Dimension(value)
#     719
#     720
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in __init__(self, value)
#     195           self._value != value):
#     196         raise ValueError("Ambiguous dimension: %s" % value)
# --> 197       if self._value < 0:
#     198         raise ValueError("Dimension %d must be >= 0" % self._value)
#     199
#
# KeyboardInterrupt:

# %%
w = 0.628025472164154
w2 = 0.1232

# %%
print(f'{w:<20.10} {w2:<20.10}')
print(f'{w2:<20.10} {w:<20.10}')
